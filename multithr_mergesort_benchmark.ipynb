# %%
import time

def single_threaded_merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]

        single_threaded_merge_sort(left)
        single_threaded_merge_sort(right)

        i = j = k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

sizes = [100, 1000, 10000]
times_mt = []
times_st = []

for size in sizes:
    arr_mt = [random.randint(0, 100000) for _ in range(size)]
    arr_st = arr_mt.copy()

    start_time = time.time()
    merge_sort(arr_mt)
    end_time = time.time()
    times_mt.append(end_time - start_time)

    start_time = time.time()
    single_threaded_merge_sort(arr_st)
    end_time = time.time()
    times_st.append(end_time - start_time)

print("Multithreaded times:", times_mt)
print("Single-threaded times:", times_st)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(sizes, times_mt, label='Multithreaded Merge Sort')
plt.plot(sizes, times_st, label='Single-threaded Merge Sort')
plt.xlabel('Array Size')
plt.ylabel('Time (s)')
plt.title('Performance Comparison')
plt.legend()
plt.show()
# Out:
# Multithreaded times: [0.0965580940246582, 1.445249319076538, 34.38815402984619]
# Single-threaded times: [0.0, 0.00951242446899414, 0.0941922664642334]
